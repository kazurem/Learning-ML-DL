# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import costs
import gradients
plt.style.use("seaborn-v0_8")

# %%
def gradientDescentLinearRegression(X: np.ndarray, y: np.ndarray, W: np.ndarray, b: np.float64, num_iters: int=100, alpha: float = 0.01, regul=False, lambda_=1):

    dj_dw = np.zeros((X.shape[1], ))
    dj_db = 0

    w_init = W
    b_init = b

    cost_history: np.float64 = np.zeros((num_iters, ));

    for i in range(num_iters):
        dj_dw, dj_db = gradients.gradientLinearRegression(X, y, W, b)

        w_init = w_init - alpha*dj_dw
        b_init = b_init - alpha*dj_db

        cost_history[i] = costs.MeanSquaredError(X, y, W, b, regul=regul, lambda_=lambda_)

        if i % 10 == 0:
            print(f"W: {w_init}; b: {b_init}; cost: {cost_history[i]}")

    return w_init, b_init,cost_history

# %%
df = pd.read_csv("data (1).csv")

# %%
plt.scatter(df['x'], df['y'], s=4)

# %%
X_train = np.array(df['x']).reshape(-1, 1)
y_train = np.array(df['y']).reshape(-1, 1)

# %%
W = np.zeros((X_train.shape[1]))
b = 0

# %%
W, b = gradientDescentLinearRegression(X_train, y_train, W, b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 W, b = gradientDescentLinearRegression(X_train, y_train, W, b)
#
# Cell In[3], line 12, in gradientDescentLinearRegression(X, y, W, b, num_iters, alpha, regul, lambda_)
#       9 cost_history: np.float64 = np.zeros((num_iters, ));
#      11 for i in range(num_iters):
# ---> 12     dj_dw, dj_db = gradients.gradientLinearRegression(X, y, W, b)
#      14     w_init = w_init - alpha*dj_dw
#      15     b_init = b_init - alpha*dj_db
#
# File ~/Documents/AI/code_AI/Learning-ML-DL/ML/gradients.py:26, in gradientLinearRegression(X, y, W, b)
#      23 dj_dw = (error - y)
#      24 dj_db = np.sum(error - y)
# ---> 26 dj_dw = np.matmul(dj_dw.T, X.T)
#      28 return dj_dw, dj_db
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 1 is different from 598)
